# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Load data

# %%
white_wine_path='../0. Project Data/Original Data/winequality-white.csv'
red_wine_path='../0. Project Data/Original Data/winequality-red.csv'

# %%
w_df=pd.read_csv(white_wine_path, sep=';')
r_df=pd.read_csv(red_wine_path, sep=';')

# %%
w_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
w_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
r_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
r_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# No missing values in either data set.

# %% [markdown]
# Checking the dtypes of each column, everything looks normal

# %%
w_df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
r_df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# ## Merging Data

# %% [markdown]
# Combining red and white wine datasets

# %%
w_df = w_df.assign(wine_type='white')

# %%
r_df = r_df.assign(wine_type='red')

# %%
df= pd.concat([w_df,r_df])

# %% [markdown]
# ## Duplicate Values

# %% [markdown]
# There seems to be many duplicate values, 1177 rows of them. The keep='first' parameter of the duplicated method marks duplicates as True except for the first occurrence.

# %%
dup_df=df[df.duplicated(keep='first')]
dup_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.2             0.230         0.32             8.5      0.058
# 5               8.1             0.280         0.40             6.9      0.050
# 7               7.0             0.270         0.36            20.7      0.045
# 8               6.3             0.300         0.34             1.6      0.049
# 20              6.2             0.660         0.48             1.2      0.029
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13             2.0      0.076
# 1564            7.2             0.695         0.13             2.0      0.076
# 1567            7.2             0.695         0.13             2.0      0.076
# 1581            6.2             0.560         0.09             1.7      0.053
# 1596            6.3             0.510         0.13             2.3      0.076
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4                    47.0                 186.0  0.99560  3.19       0.40
# 5                    30.0                  97.0  0.99510  3.26       0.44
# 7                    45.0                 170.0  1.00100  3.00       0.45
# 8                    14.0                 132.0  0.99400  3.30       0.49
# 20                   29.0                  75.0  0.98920  3.33       0.39
# ...                   ...                   ...      ...   ...        ...
# 1563                 12.0                  20.0  0.99546  3.29       0.54
# 1564                 12.0                  20.0  0.99546  3.29       0.54
# 1567                 12.0                  20.0  0.99546  3.29       0.54
# 1581                 24.0                  32.0  0.99402  3.54       0.60
# 1596                 29.0                  40.0  0.99574  3.42       0.75
#
#       alcohol  quality wine_type
# 4         9.9        6     white
# 5        10.1        6     white
# 7         8.8        6     white
# 8         9.5        6     white
# 20       12.8        8     white
# ...       ...      ...       ...
# 1563     10.1        5       red
# 1564     10.1        5       red
# 1567     10.1        5       red
# 1581     11.3        5       red
# 1596     11.0        6       red
#
# [1177 rows x 13 columns]

# %% [markdown]
# #### Group duplicates together

# %% [markdown]
# Get a count of how many of each duplicate is in the dataset

# %%
dup_grpby=dup_df.groupby(by=dup_df.columns.tolist(),as_index=False).size().sort_values(by='size', ascending=False)
dup_grpby.head(30)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 460            7.0             0.150         0.28           14.70      0.051
# 622            7.3             0.190         0.27           13.90      0.057
# 661            7.4             0.160         0.30           13.70      0.056
# 360            6.8             0.180         0.30           12.80      0.062
# 728            7.6             0.200         0.30           14.20      0.056
# 660            7.4             0.160         0.27           15.50      0.050
# 664            7.4             0.190         0.30           12.80      0.053
# 665            7.4             0.190         0.31           14.50      0.045
# 684            7.4             0.330         0.26           15.60      0.049
# 118            6.2             0.230         0.36           17.20      0.039
# 267            6.6             0.220         0.23           17.30      0.047
# 314            6.7             0.160         0.32           12.50      0.035
# 32             5.7             0.220         0.20           16.00      0.044
# 703            7.5             0.240         0.31           13.10      0.050
# 228            6.5             0.220         0.25           17.10      0.050
# 73             6.0             0.280         0.24           17.80      0.047
# 581            7.2             0.250         0.28           14.40      0.055
# 64             6.0             0.200         0.26            6.80      0.049
# 575            7.2             0.230         0.39           14.20      0.058
# 593            7.2             0.360         0.46            2.10      0.074
# 232            6.5             0.230         0.36           16.30      0.038
# 791            7.8             0.300         0.29           16.85      0.054
# 795            7.8             0.430         0.49           13.00      0.033
# 226            6.5             0.180         0.41           14.20      0.039
# 447            6.9             0.400         0.17           12.90      0.033
# 446            6.9             0.380         0.29           13.65      0.048
# 764            7.7             0.300         0.42           14.30      0.045
# 345            6.7             0.460         0.24            1.70      0.077
# 614            7.2             0.695         0.13            2.00      0.076
# 123            6.2             0.250         0.54            7.00      0.046
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 460                 29.0                 149.0  0.99792  2.96       0.39
# 622                 45.0                 155.0  0.99807  2.94       0.41
# 661                 33.0                 168.0  0.99825  2.90       0.44
# 360                 19.0                 171.0  0.99808  3.00       0.52
# 728                 53.0                 212.5  0.99900  3.14       0.46
# 660                 25.0                 135.0  0.99840  2.90       0.43
# 664                 48.5                 229.0  0.99860  3.14       0.49
# 665                 39.0                 193.0  0.99860  3.10       0.50
# 684                 67.0                 210.0  0.99907  3.06       0.68
# 118                 37.0                 130.0  0.99946  3.23       0.43
# 267                 37.0                 118.0  0.99906  3.08       0.46
# 314                 18.0                 156.0  0.99666  2.88       0.36
# 32                  41.0                 113.0  0.99862  3.22       0.46
# 703                 26.0                 180.0  0.99884  3.05       0.53
# 228                 44.0                 138.0  1.00010  3.30       0.37
# 73                  42.0                 111.0  0.99896  3.10       0.45
# 581                 55.0                 205.0  0.99860  3.12       0.38
# 64                  22.0                  93.0  0.99280  3.15       0.42
# 575                 49.0                 192.0  0.99790  2.98       0.48
# 593                 24.0                  44.0  0.99534  3.40       0.85
# 232                 43.0                 133.0  0.99924  3.26       0.41
# 791                 23.0                 135.0  0.99980  3.16       0.38
# 795                 37.0                 158.0  0.99550  3.14       0.35
# 226                 47.0                 129.0  0.99678  3.28       0.72
# 447                 59.0                 186.0  0.99754  3.08       0.49
# 446                 52.0                 189.0  0.99784  3.00       0.60
# 764                 45.0                 213.0  0.99910  3.18       0.63
# 345                 18.0                  34.0  0.99480  3.39       0.60
# 614                 12.0                  20.0  0.99546  3.29       0.54
# 123                 58.0                 176.0  0.99454  3.19       0.70
#
#      alcohol  quality wine_type  size
# 460      9.0        7     white     7
# 622      8.8        8     white     7
# 661      8.7        7     white     6
# 360      9.0        7     white     6
# 728      8.9        8     white     5
# 660      8.7        7     white     5
# 664      9.1        7     white     5
# 665      9.2        6     white     5
# 684      9.5        5     white     4
# 118      8.8        6     white     4
# 267      8.8        6     white     4
# 314      9.0        6     white     4
# 32       8.9        6     white     4
# 703      9.1        6     white     4
# 228      8.8        5     white     3
# 73       8.9        6     white     3
# 581      9.0        7     white     3
# 64      11.0        6     white     3
# 575      9.0        7     white     3
# 593     11.0        7       red     3
# 232      8.8        5     white     3
# 791      9.0        6     white     3
# 795     11.3        6     white     3
# 226     10.3        7     white     3
# 447      9.4        5     white     3
# 446      9.5        6     white     3
# 764      9.2        5     white     3
# 345     10.6        6       red     3
# 614     10.1        5       red     3
# 123     10.4        5     white     3

# %% [markdown]
# #### Check distributions of our duplicate values.

# %% [markdown]
# The distributions of these features seem a lot tighter than that of the full dataset

# %%
dup_grpby[dup_grpby.columns[:-1]].hist(figsize=(15,10))
plt.subplots_adjust(hspace=0.5);

# %% [markdown]
# Many of the features in our dataset are continuous so it is unlikely that 2 wines have the exact same features by chance.

# %% [markdown]
# Attached with the dataset was a metadata file which stated that output[quality] is based on sensory data (median of at least 3 evaluations made by wine experts). This leads us to believe that the duplicates were true duplicates and not just multiple wine tasters tasting the same wine with each recieving producing a seperate observation.

# %% [markdown]
# #### Remove duplicated rows

# %%
no_dup=df[~df.duplicated(keep='first')]
no_dup.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 6            6.2              0.32         0.16             7.0      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 6                 30.0                 136.0   0.9949  3.18       0.47
#
#    alcohol  quality wine_type
# 0      8.8        6     white
# 1      9.5        6     white
# 2     10.1        6     white
# 3      9.9        6     white
# 6      9.6        6     white

# %% [markdown]
# #### Exporting Data

# %%
no_dup_red=no_dup[no_dup['wine_type']=='red']
no_dup_white=no_dup[no_dup['wine_type']=='white']

# %%
no_dup_red.to_csv('../0. Project Data/Processed Data/1. no_duplicates/no_duplicates_red.csv', index=False)
no_dup_white.to_csv('../0. Project Data/Processed Data/1. no_duplicates/no_duplicates_white.csv', index=False)
