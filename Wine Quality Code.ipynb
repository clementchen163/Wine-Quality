# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load data

# %%
white_wine_path='./Data/winequality-white.csv'
red_wine_path='./Data/winequality-red.csv'

# %%
w_df=pd.read_csv(white_wine_path, sep=';')
r_df=pd.read_csv(red_wine_path, sep=';')

# %%
w_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
w_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
r_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
r_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# No missing values in either data set.

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# Lets start with looking at the white wine data. The units for each of the features is contained in Table 1 [Cortez et al., 2009] below. dm<sup>3</sup> represents cubic decimetres and is equivalent to 1 litre.

# %% [markdown]
# ![title](Data/wine_feature_units_table_1.png)

# %% [markdown]
# Our data is all numerical so we can look at their distributions:

# %%
w_df.hist(figsize=(15,10))
plt.subplots_adjust(hspace=0.5);

# %% [markdown]
# Using domain knowledge, we know that pH is on a scale from 0-14. There seems to be no outliers or obvious errors in pH. The features residual sugar, chlorides, free sulfur dioxide, and density look like there could be outliers present.

# %% [markdown]
# **Residual sugar**

# %% [markdown]
# It seems only 3 rows have residual sugar above 30 g/L with the average being 6.3 g/L. Two of the rows are exact duplicates of each other.

# %%
w_df['residual sugar'].mean()
# Out:
# 6.391414863209486

# %%
w_df[w_df['residual sugar'] > 30].sort_values(by='residual sugar', ascending=False)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2781            7.8             0.965         0.60            65.8      0.074
# 1653            7.9             0.330         0.28            31.6      0.053
# 1663            7.9             0.330         0.28            31.6      0.053
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2781                  8.0                 160.0  1.03898  3.39       0.69
# 1653                 35.0                 176.0  1.01030  3.15       0.38
# 1663                 35.0                 176.0  1.01030  3.15       0.38
#
#       alcohol  quality
# 2781     11.7        6
# 1653      8.8        6
# 1663      8.8        6

# %% [markdown]
# **Chlorides**

# %%
Cholrides also show some heavy outliers

# %%
w_df['chlorides'].mean()
# Out:
# 0.0457723560636995

# %%
w_df[w_df['chlorides'] > .25].sort_values(by='chlorides', ascending=False)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 484             6.2              0.37         0.30             6.6      0.346
# 1217            8.0              0.61         0.38            12.1      0.301
# 687             6.8              0.67         0.30            13.0      0.290
# 4473            7.1              0.36         0.20             1.6      0.271
# 1865            7.6              0.36         0.44             8.3      0.255
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 484                  79.0                 200.0  0.99540  3.29       0.58
# 1217                 24.0                 220.0  0.99930  2.94       0.48
# 687                  22.0                 193.0  0.99840  3.08       0.67
# 4473                 24.0                 140.0  0.99356  3.11       0.63
# 1865                 28.0                 142.0  0.99580  3.12       0.43
#
#       alcohol  quality
# 484       9.6        5
# 1217      9.2        5
# 687       9.0        4
# 4473      9.8        5
# 1865     10.2        6

# %% [markdown]
# **Free sulfur dioxide**

# %%
w_df['free sulfur dioxide'].mean()
# Out:
# 35.30808493262556

# %%
w_df[w_df['free sulfur dioxide'] > 125].sort_values(by='free sulfur dioxide', ascending=False)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4745            6.1             0.260         0.25             2.9      0.047
# 1931            7.1             0.490         0.22             2.0      0.047
# 3050            6.2             0.255         0.24             1.7      0.039
# 325             7.5             0.270         0.31             5.8      0.057
# 2334            7.5             0.230         0.35            17.8      0.058
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4745                289.0                 440.0  0.99314  3.44       0.64
# 1931                146.5                 307.5  0.99240  3.24       0.37
# 3050                138.5                 272.0  0.99452  3.53       0.53
# 325                 131.0                 313.0  0.99460  3.18       0.59
# 2334                128.0                 212.0  1.00241  3.44       0.43
#
#       alcohol  quality
# 4745     10.5        3
# 1931     11.0        3
# 3050      9.6        4
# 325      10.5        5
# 2334      8.9        5

# %% [markdown]
# From some quick research, it seems like total sulfur dioxide is the sum of free sulfur dioxide and bound sulfur dioxide. We should check for rows where there is more free sulfur dioxide than total sulfur dioxide. When modeling, we should consider use of only one of these features as multi collinearity issue may arise otherwise.

# %%
w_df[w_df['total sulfur dioxide'].sub(w_df['free sulfur dioxide'])<0]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %% [markdown]
# There doesn't seem to be any obvious errors. Let check how related these two features are

# %%
plt.scatter(w_df['total sulfur dioxide'],w_df['free sulfur dioxide'])
plt.xlabel('total sulfur dioxide')
plt.ylabel('free sulfur dioxide')
plt.show()

# %% [markdown]
# **Density**

# %% [markdown]
# Here the density of all the wines is very close to 1 g/cm<sup>3</sup> which is the density of water. There exists only 3 outliers with densities above 1.01 and again we see that 2 of the 3 rows are duplicates of each other. These 3 rows are also the 3 rows that showed up as outliers in the residual sugars column

# %%
w_df.density.mean()
# Out:
# 0.9940273764801896

# %%
w_df[w_df['density'] > 1.01].sort_values(by='density', ascending=False)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2781            7.8             0.965         0.60            65.8      0.074
# 1653            7.9             0.330         0.28            31.6      0.053
# 1663            7.9             0.330         0.28            31.6      0.053
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2781                  8.0                 160.0  1.03898  3.39       0.69
# 1653                 35.0                 176.0  1.01030  3.15       0.38
# 1663                 35.0                 176.0  1.01030  3.15       0.38
#
#       alcohol  quality
# 2781     11.7        6
# 1653      8.8        6
# 1663      8.8        6

# %% [markdown]
# Lets drop these outliers from our dataset

# %%
w_df.drop(labels=[2781,1653,1663], axis=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-b7fa0c4b7b52> in <module>
#       1 w_df.size
# ----> 2 w_df.drop(labels=[2781,1653,1663], axis=0, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: '[2781, 1653, 1663] not found in axis'

# %%
w_df[w_df.duplicated(keep='first')]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.2              0.23         0.32             8.5      0.058
# 5               8.1              0.28         0.40             6.9      0.050
# 7               7.0              0.27         0.36            20.7      0.045
# 8               6.3              0.30         0.34             1.6      0.049
# 20              6.2              0.66         0.48             1.2      0.029
# ...             ...               ...          ...             ...        ...
# 4828            6.4              0.23         0.35            10.3      0.042
# 4850            7.0              0.36         0.35             2.5      0.048
# 4851            6.4              0.33         0.44             8.9      0.055
# 4856            7.1              0.23         0.39            13.7      0.058
# 4880            6.6              0.34         0.40             8.1      0.046
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4                    47.0                 186.0  0.99560  3.19       0.40
# 5                    30.0                  97.0  0.99510  3.26       0.44
# 7                    45.0                 170.0  1.00100  3.00       0.45
# 8                    14.0                 132.0  0.99400  3.30       0.49
# 20                   29.0                  75.0  0.98920  3.33       0.39
# ...                   ...                   ...      ...   ...        ...
# 4828                 54.0                 140.0  0.99670  3.23       0.47
# 4850                 67.0                 161.0  0.99146  3.05       0.56
# 4851                 52.0                 164.0  0.99488  3.10       0.48
# 4856                 26.0                 172.0  0.99755  2.90       0.46
# 4880                 68.0                 170.0  0.99494  3.15       0.50
#
#         alcohol  quality
# 4      9.900000        6
# 5     10.100000        6
# 7      8.800000        6
# 8      9.500000        6
# 20    12.800000        8
# ...         ...      ...
# 4828   9.200000        5
# 4850  11.100000        6
# 4851   9.600000        5
# 4856   9.000000        6
# 4880   9.533333        6
#
# [937 rows x 12 columns]

# %%
w_df.groupby(w_df.columns.tolist(),as_index=False).size().sort_values(by='size', ascending=False).head(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2389            7.0              0.15         0.28            14.7      0.051
# 2881            7.3              0.19         0.27            13.9      0.057
# 3000            7.4              0.16         0.30            13.7      0.056
# 1973            6.8              0.18         0.30            12.8      0.062
# 3019            7.4              0.19         0.30            12.8      0.053
# 3255            7.6              0.20         0.30            14.2      0.056
# 2998            7.4              0.16         0.27            15.5      0.050
# 3020            7.4              0.19         0.31            14.5      0.045
# 252             5.7              0.22         0.20            16.0      0.044
# 3105            7.4              0.33         0.26            15.6      0.049
# 1771            6.7              0.16         0.32            12.5      0.035
# 838             6.2              0.23         0.36            17.2      0.039
# 3169            7.5              0.24         0.31            13.1      0.050
# 1569            6.6              0.22         0.23            17.3      0.047
# 2352            6.9              0.40         0.17            12.9      0.033
# 2086            6.8              0.27         0.30            13.0      0.047
# 3491            7.8              0.43         0.49            13.0      0.033
# 858             6.2              0.25         0.54             7.0      0.046
# 3058            7.4              0.25         0.36            13.2      0.067
# 2925            7.3              0.25         0.36            13.1      0.050
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2389                 29.0                 149.0  0.99792  2.96       0.39
# 2881                 45.0                 155.0  0.99807  2.94       0.41
# 3000                 33.0                 168.0  0.99825  2.90       0.44
# 1973                 19.0                 171.0  0.99808  3.00       0.52
# 3019                 48.5                 229.0  0.99860  3.14       0.49
# 3255                 53.0                 212.5  0.99900  3.14       0.46
# 2998                 25.0                 135.0  0.99840  2.90       0.43
# 3020                 39.0                 193.0  0.99860  3.10       0.50
# 252                  41.0                 113.0  0.99862  3.22       0.46
# 3105                 67.0                 210.0  0.99907  3.06       0.68
# 1771                 18.0                 156.0  0.99666  2.88       0.36
# 838                  37.0                 130.0  0.99946  3.23       0.43
# 3169                 26.0                 180.0  0.99884  3.05       0.53
# 1569                 37.0                 118.0  0.99906  3.08       0.46
# 2352                 59.0                 186.0  0.99754  3.08       0.49
# 2086                 69.0                 160.0  0.99705  3.16       0.50
# 3491                 37.0                 158.0  0.99550  3.14       0.35
# 858                  58.0                 176.0  0.99454  3.19       0.70
# 3058                 53.0                 178.0  0.99760  3.01       0.48
# 2925                 35.0                 200.0  0.99860  3.04       0.46
#
#       alcohol  quality  size
# 2389      9.0        7     8
# 2881      8.8        8     8
# 3000      8.7        7     7
# 1973      9.0        7     7
# 3019      9.1        7     6
# 3255      8.9        8     6
# 2998      8.7        7     6
# 3020      9.2        6     6
# 252       8.9        6     5
# 3105      9.5        5     5
# 1771      9.0        6     5
# 838       8.8        6     5
# 3169      9.1        6     5
# 1569      8.8        6     5
# 2352      9.4        5     4
# 2086      9.6        6     4
# 3491     11.3        6     4
# 858      10.4        5     4
# 3058      9.0        6     4
# 2925      8.9        7     4
